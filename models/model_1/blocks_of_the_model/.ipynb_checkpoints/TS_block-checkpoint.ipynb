# %%
this part should be completed.
# Out:
#   Cell In[1], line 1
#     this part should be completed.
#          ^
# SyntaxError: invalid syntax

# %%
import torch
import torch.nn as nn
import math
from Transformer_Encoder import *

# %%
class token_selection(nn.Module):
    def __init__(self, ):
        pass


    def forward(self, ):
        pass

# %%
class TS_block(nn.Module):
    def __init__(self,  d_model: int,  num_heads: int,  d_ff: int,  self.m: int):
        self.d_model=d_model
        self.num_heads=num_heads
        self.d_ff=d_ff
        
        super().__init__() 

        self.teb=teb(
            d_model=self.d_model,
            num_heads=self.num_heads,
            d_ff=self.d_ff
        )
        
        self.k=self.m*(0.25)

        self.token_selection=token_selection(k=self.k)
        


        
    def forward(self, x):
        x1=self.teb(x)
        x2=self.token_selection(x1)
        x3=self.teb(x2)

        return x3[0]   #returns cls-token
