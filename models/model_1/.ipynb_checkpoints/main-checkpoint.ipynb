# %%
from load_dataset import *

# %%
if not "dataset" in os.listdir():
    ldob=load_dataset()
    ldob.load_dataset()
    ldob.denoise_signals()
    ldob.reduce_sample_rate()
    ldob.define_labels()
    ldob.define_8_superclasses()
    ldob.one_hot_encodding()

    signals, labels=ldob.get_signals_and_labels()

    if "dataset" in os.listdir():
        shutil.rmtree("dataset")
    os.mkdir("dataset")
    np.save("dataset/signals.npy", signals)
    np.save("dataset/labels.npy",  labels)

else:
    signals=np.load("dataset/signals.npy")
    labels=np.load("dataset/labels.npy")


print("signals.shape:  ", signals.shape)
print("labels.shape:   ", labels.shape)
# Out:
# Do you want to see the logs?
# 1-Yes         0-No 1
#  -->Enter how many instances you want to load:  10
# load_dataset()
#   first 10 instances of the dataset are loaded
# ----------------------------------------------------------------
#
#
#
#
# denoise_signal()
#   All instances are denoised by Neurokit2.
# 	hint:
# 		 signals_shape=(batch_number, time_steps, features) as bellow: :
# 			 -> (10, 5000, 12)
# ----------------------------------------------------------------
#
#
#
#
# reduce_sample_rate()
#   sample-rate is reduced from 500HZ to 100HZ.
# 	hint:
# 		 signals_shape=(batch_number, timesteps, features) as bellow :
# 			 -> (10, 1000, 12)
# ----------------------------------------------------------------
#
#
#
#
# define_labels()
#   The labels of the instances are extracted from self.record_array.
# ----------------------------------------------------------------
#
#
#
#
# define_8_superclasses()
#   8 superclasses based on Dr.Teimouri's suggestion are created.
# 	hint:
# 		 super_classes_log :
# 			 -> superclasses are as bellow
#
#
# super-classes with their sub-classes
#
#
#
# -----------------
# 0  Standard
# 	SR,	Sinus Rhythm
#
#
#
#
# -----------------
# 1  Bradyarrhythmia
# 	1AVB,	1 degree atrioventricular block
#
# 	2AVB,	2 degree atrioventricular block
#
# 	2AVB1,	2 degree atrioventricular block(Type one)
#
# 	2AVB2,	2 degree atrioventricular block(Type two)
#
# 	3AVB,	3 degree atrioventricular block
#
# 	AVB,	atrioventricular block
#
# 	JEB,	junctional escape beat
#
# 	PRIE,	PR interval extension
#
# 	SB,	Sinus Bradycardia
#
#
#
#
# -----------------
# 2  Ischemia and ST-T changes
# 	MI,	myocardial infarction
#
# 	MIBW,	myocardial infraction in back wall
#
# 	MIFW,	Myocardial infgraction in the front wall
#
# 	MILW,	Myocardial infraction in the lower wall
#
# 	MISW,	Myocardial infraction in the side wall
#
# 	STDD,	ST drop down
#
# 	STE,	ST extension
#
# 	STTC,	ST-T Change
#
# 	STTU,	ST tilt up
#
# 	TWC,	T wave Change
#
# 	TWO,	T wave opposite
#
# 	UW,	U wave
#
#
#
#
# -----------------
# 3  Ventricular arrhythmia
# 	VB,	ventricular bigeminy
#
# 	VEB,	ventricular escape beat
#
# 	VFW,	ventricular fusion wave
#
# 	VPB,	ventricular premature beat
#
# 	VET,	ventricular escape trigeminy
#
#
#
#
# -----------------
# 4  Supraventricular arrhythmia
# 	ABI,	atrial bigeminy
#
# 	APB,	atrial premature beats
#
# 	JPT,	junctional premature beat
#
# 	AFIB,	Atrial Fibrillation
#
# 	ST,	Sinus Tachycardia
#
# 	AF,	Atrial Flutter
#
# 	SA,	Sinus Irregularity
#
# 	SVT,	Supraventricular Tachycardia
#
# 	AT,	Atrial Tachycardia
#
# 	AVNRT,	Atrioventricular  Node Reentrant Tachycardia
#
# 	AVRT,	Atrioventricular Reentrant Tachycardia
#
# 	SAAWR,	Sinus Atrium to Atrial Wandering Rhythm
#
#
#
#
# -----------------
# 5  Bundle branch abnormalities
# 	IDC,	Interior differences conduction
#
# 	IVB,	Intraventricular block
#
# 	LBBB,	left bundle branch block
#
# 	LBBBB,	left back bundle branch block
#
# 	LFBBB,	left front bundle branch block
#
# 	LVH,	left ventricle hypertrophy
#
# 	RBBB,	right bundle branch block
#
# 	RVH,	right ventricle hypertrophy
#
#
#
#
# -----------------
# 6  Abnormal parameters in ECG
# 	ALS,	Axis left shift
#
# 	AQW,	abnormal Q wave
#
# 	ARS,	Axis right shift
#
# 	LVQRSAL,	lower voltage QRS in all lead
#
# 	LVQRSCL,	lower voltage QRS in chest lead
#
# 	LVQRSLL,	lower voltage QRS in limb lead
#
# 	QTIE,	QT interval extension
#
# 	RAH,	right atrial hypertrophy
#
#
#
#
# -----------------
# 7  Pre-excitation
# 	VPE,	ventricular preexcitation
#
# 	WPW,	WPW
#
#
#
#
# -----------------
# 8  delete_all_of_them
# 	CCR,	countercolockwise rotation
#
# 	CR,	colockwise rotation
#
# 	ERV,	Early repolarization of the ventricles
#
# 	FQRS,	fQRS Wave
#
# 	PWC,	P wave Change
#
# 	WAVN,	Wandering in the atrioventricalualr node
#
#
#
#
# ----------------------------------------------------------------
#
#
#
#
# one_hot_encodding()
#   one-hot encodding functions are applied on the dataset
# 	hint:
# 		 outputs :
# 			 -> signals: numpy array that includes 12-lead ECG signal.
# 			 -> labels : one-hot encodded numpy array of diagnosed labels.
# 			 -> The signals with this indices have no label, so they are romoved:
# 				[]
#
#
# ----------------------------------------------------------------
#
#
#
#
# signals.shape:   (10, 12, 1000)
# labels.shape:    (10, 8)
